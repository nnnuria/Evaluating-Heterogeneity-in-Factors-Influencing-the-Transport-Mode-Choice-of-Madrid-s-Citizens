# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score
import shap
import optuna
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('cluster_5.csv')
df = df.dropna(subset=['pv_for_trip.'])

# %%
X = df[['sex','age_group','spanish','driving_license_binary','educ_group','main_activity_group','prof_status_group','transport_card_binary','mobility_issue','ppl_hh','pp_4age_hh','vehicles_hh','private_parking.','electric.','trips_hh','primary_reason','distance_km','rush_hour_75.','travel_freq','pv_for_trip.','temp','precip']]
y = df[['primary_mode_group']]

# %%
categorical_cols = ['sex', 'age_group','spanish','driving_license_binary','educ_group','main_activity_group','prof_status_group','transport_card_binary','mobility_issue','private_parking.','electric.','primary_reason','pv_for_trip.']

# %%
X_dummies = pd.get_dummies(X, columns=categorical_cols)

# %%
rename_dict = {
    'rush_hour_75.' : 'rush_hour_75%',
    'ppl_hh': 'household_size',
    'pp_4age_hh': 'household_members_4plus',
    'vehicles_hh': 'household_vehicles',
    'trips_hh': 'household_trip_count',
    'sex_1': 'gender_male',
    'sex_2': 'gender_female',
    'age_group_1': 'age_below_18',
    'age_group_2': 'age_18_to_29',
    'age_group_3': 'age_30_to_59',
    'age_group_4': 'age_60plus',
    'spanish_1': 'spanish_nationality',
    'spanish_2': 'spanish_nationality_no',
    'driving_license_binary_0': 'has_driving_license_no',
    'driving_license_binary_1': 'has_driving_license',
    'educ_group_1': 'education_primary_or_less',
    'educ_group_2': 'education_secondary',
    'educ_group_3': 'education_bachelor_or_higher',
    'educ_group_4': 'education_other',
    'main_activity_group_1': 'main_activity_employed',
    'main_activity_group_2': 'main_activity_retired',
    'main_activity_group_3': 'main_activity_unemployed',
    'main_activity_group_4': 'main_activity_student',
    'prof_status_group_1': 'prof_status_public_employee',
    'prof_status_group_2': 'prof_status_private_employee',
    'prof_status_group_3': 'prof_status_own_or_family_business',
    'prof_status_group_4': 'prof_status_other',
    'prof_status_group_5': 'prof_status_unemployed',
    'transport_card_binary_0': 'has_transport_card_no',
    'transport_card_binary_1': 'has_transport_card_yes',
    'mobility_issue_1': 'mobility_issue',
    'mobility_issue_2': 'mobility_issue_no',
    'private_parking._0': 'private_parking_no',
    'private_parking._1': 'private_parking_yes',
    'electric._0': 'electric_or_hybrid_transport_no',
    'electric._1': 'electric_or_hybrid_transport',
    'primary_reason_1': 'trip_reason_work',
    'primary_reason_2': 'trip_reason_study',
    'primary_reason_3': 'trip_reason_entertainment',
    'primary_reason_4': 'trip_reason_accompany_others',
    'primary_reason_5': 'trip_reason_personal_matters',
    'primary_reason_6': 'trip_reason_other',
    'pv_for_trip._1.0':'private_vehicle_used',
    'pv_for_trip._2.0':'private_vehicle_used_no'
}

# %%
X_dummies = X_dummies.rename(columns=rename_dict)

# %%
# make sure categories start from 0
y['primary_mode_group'] = y['primary_mode_group'] - 1
# Out:
# /var/folders/ps/rsyy3fxx1fq6dzs0frkt8hl80000gn/T/ipykernel_32804/1151536143.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['primary_mode_group'] = y['primary_mode_group'] - 1

# %%
y = y.values.ravel()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.3, random_state=42)

# %%
def rf_objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 100, 500)
    max_depth = trial.suggest_int("max_depth", 3, 20)
    
    rf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )
    
    score = cross_val_score(rf, X_train, y_train, cv=5, scoring='accuracy')
    return score.mean()

rf_study = optuna.create_study(direction="maximize")
rf_study.optimize(rf_objective, n_trials=20)

print("Best RF parameters:", rf_study.best_params)
# Out:
# [I 2025-04-10 09:43:16,154] A new study created in memory with name: no-name-759ecadb-0fda-4fec-9cd7-a906edb5823a
# [I 2025-04-10 09:43:41,400] Trial 0 finished with value: 0.7466346718468191 and parameters: {'n_estimators': 382, 'max_depth': 12}. Best is trial 0 with value: 0.7466346718468191.
# [I 2025-04-10 09:44:00,441] Trial 1 finished with value: 0.7472624328368784 and parameters: {'n_estimators': 299, 'max_depth': 12}. Best is trial 1 with value: 0.7472624328368784.
# [I 2025-04-10 09:44:16,917] Trial 2 finished with value: 0.7676292075686745 and parameters: {'n_estimators': 231, 'max_depth': 14}. Best is trial 2 with value: 0.7676292075686745.
# [I 2025-04-10 09:44:43,375] Trial 3 finished with value: 0.7576551194803386 and parameters: {'n_estimators': 392, 'max_depth': 13}. Best is trial 2 with value: 0.7676292075686745.
# [I 2025-04-10 09:44:51,217] Trial 4 finished with value: 0.7196067690269791 and parameters: {'n_estimators': 157, 'max_depth': 9}. Best is trial 2 with value: 0.7676292075686745.
# [I 2025-04-10 09:45:14,594] Trial 5 finished with value: 0.768082606724325 and parameters: {'n_estimators': 326, 'max_depth': 14}. Best is trial 5 with value: 0.768082606724325.
# [I 2025-04-10 09:45:21,349] Trial 6 finished with value: 0.7364861185318672 and parameters: {'n_estimators': 111, 'max_depth': 11}. Best is trial 5 with value: 0.768082606724325.
# [I 2025-04-10 09:45:53,679] Trial 7 finished with value: 0.8048406832521957 and parameters: {'n_estimators': 373, 'max_depth': 20}. Best is trial 7 with value: 0.8048406832521957.
# [I 2025-04-10 09:46:13,967] Trial 8 finished with value: 0.7578992588907416 and parameters: {'n_estimators': 289, 'max_depth': 13}. Best is trial 7 with value: 0.8048406832521957.
# [I 2025-04-10 09:46:35,178] Trial 9 finished with value: 0.8050150207590265 and parameters: {'n_estimators': 244, 'max_depth': 20}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:46:48,235] Trial 10 finished with value: 0.6555767475791778 and parameters: {'n_estimators': 491, 'max_depth': 3}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:47:08,535] Trial 11 finished with value: 0.804526766265799 and parameters: {'n_estimators': 234, 'max_depth': 20}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:47:47,523] Trial 12 finished with value: 0.8046314417526317 and parameters: {'n_estimators': 447, 'max_depth': 20}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:48:06,083] Trial 13 finished with value: 0.7915883445356762 and parameters: {'n_estimators': 223, 'max_depth': 17}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:48:36,176] Trial 14 finished with value: 0.7922857675457335 and parameters: {'n_estimators': 363, 'max_depth': 17}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:49:12,147] Trial 15 finished with value: 0.7924252983701436 and parameters: {'n_estimators': 435, 'max_depth': 17}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:49:20,762] Trial 16 finished with value: 0.7113065277886322 and parameters: {'n_estimators': 174, 'max_depth': 8}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:49:43,426] Trial 17 finished with value: 0.7974472464070448 and parameters: {'n_estimators': 268, 'max_depth': 18}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:50:13,464] Trial 18 finished with value: 0.8048058461603024 and parameters: {'n_estimators': 342, 'max_depth': 20}. Best is trial 9 with value: 0.8050150207590265.
# [I 2025-04-10 09:50:24,627] Trial 19 finished with value: 0.6561696836411329 and parameters: {'n_estimators': 417, 'max_depth': 3}. Best is trial 9 with value: 0.8050150207590265.
# Best RF parameters: {'n_estimators': 244, 'max_depth': 20}

# %%
def xgb_objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 100, 500)
    max_depth = trial.suggest_int("max_depth", 3, 20)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
    
    model = XGBClassifier(
        objective='multi:softprob',
        num_class = len(np.unique(y)),
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        eval_metric='mlogloss',
        random_state=42
    )
    
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
. Best is trial 9 with value: 0.7986679434590593.
# [I 2025-04-10 10:01:29,914] Trial 18 finished with value: 0.7984238405400237 and parameters: {'n_estimators': 253, 'max_depth': 17, 'learning_rate': 0.07873377679932805}. Best is trial 9 with value: 0.7986679434590593.
# [I 2025-04-10 10:01:56,994] Trial 19 finished with value: 0.7991561918703923 and parameters: {'n_estimators': 175, 'max_depth': 18, 'learning_rate': 0.18693714273866316}. Best is trial 19 with value: 0.7991561918703923.
# Best XGB params: {'n_estimators': 175, 'max_depth': 18, 'learning_rate': 0.18693714273866316}

# %%
#Train final models with best hyperparameters 
best_rf = RandomForestClassifier(**rf_study.best_params, random_state=42)
best_rf.fit(X_train, y_train)
y_pred_rf = best_rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print("Final RF accuracy:", rf_accuracy)

best_xgb = XGBClassifier(
    **xgb_study.best_params,
    objective='multi:softprob',
    num_class = len(np.unique(y)),
    eval_metric='mlogloss',
    random_state=42
)
best_xgb.fit(X_train, y_train)
y_pred_xgb = best_xgb.predict(X_test)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print("Final XGB accuracy:", xgb_accuracy)
# Out:
# Final RF accuracy: 0.8247355573637103
# Final XGB accuracy: 0.8225386493083808

# %%
#Model performance weights
rf_f1 = f1_score(y_test, best_rf.predict(X_test), average='macro')
xgb_f1 = f1_score(y_test, best_xgb.predict(X_test), average='macro')

rf_weight = rf_f1 / (rf_f1 + xgb_f1)
xgb_weight = xgb_f1 / (rf_f1 + xgb_f1)

print(f" F1 score: {rf_f1:.4f}, XGB F1 score: {xgb_f1:.4f}")
print(f"RF weight: {rf_weight:.4f}, XGB weight: {xgb_weight:.4f}")
# Out:
#  F1 score: 0.6761, XGB F1 score: 0.6708
# RF weight: 0.5020, XGB weight: 0.4980

# %%
#Use a sub sample representative enough for time reasons 
X_test_sample = X_test.sample(n=3000, random_state=42)

# %%
explainer_rf = shap.TreeExplainer(best_rf)
shap_values_rf = explainer_rf.shap_values(X_test_sample)

# %%
explainer_xgb = shap.TreeExplainer(best_xgb)
shap_values_xgb = explainer_xgb.shap_values(X_test_sample)

# %% [markdown]
# SHAP PER CLASS COMBINED XGB AND RF

# %%
n_classes = shap_values_rf.shape[2]
class_names = ['Walking',"Car",'Metro', 'Bus','Rail','Other']
for c in range(n_classes):
    shap_rf_c = shap_values_rf[:, :, c]
    shap_xgb_c = shap_values_xgb[:, :, c]
    
    combined_shap_c = rf_weight *  shap_rf_c + xgb_weight * shap_xgb_c
    
    print(f"Summary plot for class {c}:")
    shap.summary_plot(combined_shap_c, X_test_sample, feature_names=X_test_sample.columns, plot_type="dot", show=False,plot_size=(5,5))
    class_name = class_names[c]
    plt.title(f"Class: {class_name}", fontsize=10)
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    plt.xlabel("SHAP value (impact on model output)", fontsize=8)
    plt.tight_layout()
    plt.show()
# Out:
# Summary plot for class 0:
# Summary plot for class 1:
# Summary plot for class 2:
# Summary plot for class 3:
# Summary plot for class 4:
# Summary plot for class 5:

# %% [markdown]
# GLOBAL SHAP

# %%
# use predicted probabilities for each class as weights for per-class SHAP values
p_rf = best_rf.predict_proba(X_test_sample)
p_xgb = best_xgb.predict_proba(X_test_sample)
p_rf_reshaped = p_rf[:, None, :]  
p_xgb_reshaped = p_xgb[:, None, :]

# %%
phi_rf_weighted = rf_weight * p_rf_reshaped * shap_values_rf 
phi_xgb_weighted = xgb_weight * p_xgb_reshaped * shap_values_xgb

# %%
phi_combined = phi_rf_weighted + phi_xgb_weighted
phi_combined_abs = np.abs(phi_combined)
phi_summed_over_classes = np.sum(phi_combined_abs, axis=2)

# %%
shap.summary_plot(phi_summed_over_classes, X_test_sample, feature_names=X_test_sample.columns, plot_type="bar", plot_size=(6,4), show=False)
plt.title("Cluster 5", fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel("mean(|SHAP value|) (average impact on model output magnitude)", fontsize=8)
plt.tight_layout()
plt.show()
